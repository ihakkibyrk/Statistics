# %% [markdown]
# Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# #**Descriptive Statistics**

# %% [markdown]
# [Seaborn Datasets](https://github.com/mwaskom/seaborn-data)

# %% [markdown]
# [Titanic dataset](https://www.kaggle.com/brendan45774/test-file)

# %%
# Load Titanic Dataset

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Discuss The Dataset

# %%
df.fare.dtype
# Out:
# dtype('float64')

# %%
fare = np.array(df.fare)

# %%
fare
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#          7.8958,  41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,
#         21.6792,  17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,
#         61.9792,  35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,
#          7.2292,  80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,
#         10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,
#         73.5   ,  14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,
#         29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,
# ...

# %%
len(fare)
# Out:
# 891

# %%
fare.shape
# Out:
# (891,)

# %%
fare.reshape(9,-1).shape
# Out:
# (9, 99)

# %%
# Central Tendency Measures

# %%
np.mean(fare)
# Out:
# 32.204207968574636

# %%
np.median(fare)
# Out:
# 14.4542

# %%
stats.mode(fare)
# Out:
# ModeResult(mode=array([8.05]), count=array([43]))

# %%
stats.describe(fare)
# Out:
# DescribeResult(nobs=891, minmax=(0.0, 512.3292), mean=32.204207968574636, variance=2469.436845743116, skewness=4.7792532923723545, kurtosis=33.20428925264474)

# %%
np.min(fare)
# Out:
# 0.0

# %%
np.max(fare)
# Out:
# 512.3292

# %%
# Visualize

# %%
plt.hist(fare);

# %%
plt.boxplot(fare);

# %%
stats.iqr(fare)
# Out:
# 23.0896

# %%
new_fare = fare[fare < 100]

# %%
plt.boxplot(new_fare);

# %%
plt.hist(new_fare);

# %%
stats.skew(new_fare)
# Out:
# 1.6690093839471292

# %%
stats.skew(fare)
# Out:
# 4.7792532923723545

# %%
sns.kdeplot(new_fare)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Dispersion Measures

# %%
np.var(new_fare)
# Out:
# 433.2553602824674

# %%
np.std(new_fare)
# Out:
# 20.814787058302265

# %%
np.max(new_fare) - np.min(new_fare)  # range
# Out:
# 93.5

# %%
q1 = np.percentile(new_fare, 25)
q3 = np.percentile(new_fare, 75)
iqr = q3 - q1
iqr == stats.iqr(new_fare)
# Out:
# True

# %%
print('q1: ',q1,'median: ',np.median(new_fare),'q3: ',q3,'iqr: ',iqr)
# Out:
# q1:  7.8958 median:  13.0 q3:  27.7208 iqr:  19.825

# %%
# Scatter Plot

# %%
#tv_hours vs GPA
tv_hours = np.array([3,5,2,0,5,3,1,4,3,4])
GPA = np.array([2.7,2.1,3.3,3.4,2.0,3.0,3.6,2.8,3.5,2.6])

# %%
plt.scatter(tv_hours, GPA)

# %%
sns.scatterplot(tv_hours, GPA);
# Out:
# C:\Users\ihakk\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Draw a fitting Line

# %%
m,b = np.polyfit(tv_hours, GPA, 1)
plt.plot(tv_hours, GPA, 'o')
plt.plot(tv_hours, m*tv_hours + b);

# %% [markdown]
# # **Correlation**

# %% [markdown]
# ![correlation.PNG](data:image/png;base64,...)

# %% [markdown]
# # Manuel (with Formula)

# %%
#tv_hours vs GPA
tv_hours = [3,5,2,0,5,3,1,4,3,4]
GPA = [2.7,2.1,3.3,3.4,2.0,3.0,3.6,2.8,3.5,2.6]

# %% [markdown]
# Convert the lists to Numpy arrays

# %%
x = tv_hours
y = GPA

# %% [markdown]
# ![correlation1.PNG](data:image/png;base64,...)

# %% [markdown]
# Use Pearson Correlation Formula. First calculate the numerator, second calculate the denominator, then calculate r coeff.

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.85697808],
#        [-0.85697808,  1.        ]])

# %%
numer = len(x)*sum(x*y) - sum(x)*sum(y)
numer
# Out:
# -71.00000000000011

# %%
denom = np.sqrt((len(x)*sum(x**2)- sum(x)**2)*(len(y)*sum(y**2)-sum(y)**2))
denom
# Out:
# 82.84926070883178

# %%
r = numer/denom
r
# Out:
# -0.8569780755138527

# %% [markdown]
# # Scipy

# %%
r, p = stats.pearsonr(x,y)
r
# Out:
# -0.8569780755138502

# %%
p
# Out:
# 0.0015347436269997083

# %% [markdown]
# The Spearman rank-order correlation coefficient is a nonparametric measure of the monotonicity of the relationship between two datasets. Unlike the Pearson correlation, the Spearman correlation does not assume that both datasets are normally distributed.

# %%
stats.spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=-0.8643457510060754, pvalue=0.0012537299375704556)

# %% [markdown]
# Calculate Kendall’s tau, a correlation measure for ordinal data.
#
# Kendall’s tau is a measure of the correspondence between two rankings.

# %%
stats.kendalltau(x,y)
# Out:
# KendalltauResult(correlation=-0.7542472332656507, pvalue=0.0033968772424454747)

# %% [markdown]
# ## Numpy

# %% [markdown]
# Calculate covariance with Numpy

# %%
np.cov(x,y)
# Out:
# array([[ 2.66666667, -0.78888889],
#        [-0.78888889,  0.31777778]])

# %%
stats.tvar(x)
# Out:
# 2.6666666666666665

# %% [markdown]
# Calculate the sample variances

# %%
np.var(x)
# Out:
# 2.4

# %% [markdown]
# Calculate the correlation coefficients with Numpy

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.85697808],
#        [-0.85697808,  1.        ]])
